# %% [markdown]
# <a href="https://colab.research.google.com/github/ATNK1606/Projet_hotel/blob/main/Projet_maths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Priorité
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10
import pandas as pd

# =========================
# 1. Chargement des données
# =========================
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Sélection de deux classes (ex: avion=0, voiture=1)
classes = [0, 1]

train_mask = np.isin(y_train, classes).flatten()
test_mask = np.isin(y_test, classes).flatten()

X_train, y_train = X_train[train_mask], y_train[train_mask]
X_test, y_test = X_test[test_mask], y_test[test_mask]

# Re-normalisation
X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0

# Re-labeling (0 et 1)
y_train = (y_train == classes[1]).astype(int)
y_test = (y_test == classes[1]).astype(int)

y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)

# =========================
# 2. Construction du CNN
# =========================
model = Sequential()

model.add(Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3)))
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(2, activation='softmax'))

# =========================
# 3. Compilation
# =========================
model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# =========================
# 4. Entraînement
# =========================
epochs = 5
batch_size = 32

history = model.fit(
    X_train, y_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_split=0.2
)

# =========================
# 5. Tableau des epochs
# =========================
df_epochs = pd.DataFrame({
    "Epoch": range(1, epochs + 1),
    "Loss": history.history["loss"],
    "Accuracy": history.history["accuracy"],
    "Val Loss": history.history["val_loss"],
    "Val Accuracy": history.history["val_accuracy"]
})

print("\n=== Résultats par epoch ===")
print(df_epochs)

# =========================
# 6. Évaluation finale (TEST)
# =========================
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print("\n=== Résultat FINAL ===")
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

# =========================
# 7. Sauvegarde NUMPY
# =========================
results = {
    "epoch_table": df_epochs.to_dict(orient="list"),
    "final_train_accuracy": history.history["accuracy"][-1],
    "final_val_accuracy": history.history["val_accuracy"][-1],
    "test_accuracy": test_accuracy,
    "test_loss": test_loss
}

np.save("IngenierieMath_DM_2025_KEITA_Amadou_Tamba_Namory.npy", results)

print("\nFichier .npy sauvegardé avec succès.")
# Out:
# Epoch 1/5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 151ms/step - accuracy: 0.7631 - loss: 0.4755 - val_accuracy: 0.8910 - val_loss: 0.2765
# Epoch 2/5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - accuracy: 0.9110 - loss: 0.2299 - val_accuracy: 0.9300 - val_loss: 0.1786
# Epoch 3/5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 149ms/step - accuracy: 0.9364 - loss: 0.1589 - val_accuracy: 0.9370 - val_loss: 0.1663
# Epoch 4/5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 36s 146ms/step - accuracy: 0.9552 - loss: 0.1154 - val_accuracy: 0.9465 - val_loss: 0.1293
# Epoch 5/5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 147ms/step - accuracy: 0.9608 - loss: 0.0961 - val_accuracy: 0.9485 - val_loss: 0.1257
#
# === Résultats par epoch ===
#    Epoch      Loss  Accuracy  Val Loss  Val Accuracy
# 0      1  0.383610  0.825750  0.276533        0.8910
# 1      2  0.211821  0.916500  0.178624        0.9300
# 2      3  0.153705  0.938500  0.166328        0.9370
# 3      4  0.116141  0.955000  0.129274        0.9465
# ...

# %%
import numpy as np

data = np.load("IngenierieMath_DM_2025_KEITA_Amadou_Tamba_Namory.npy", allow_pickle=True).item()
print(data)
# Out:
# {'epoch_table': {'Epoch': [1, 2, 3, 4, 5], 'Loss': [0.3836098909378052, 0.2118205726146698, 0.15370479226112366, 0.11614111065864563, 0.09054241329431534], 'Accuracy': [0.8257499933242798, 0.9164999723434448, 0.9384999871253967, 0.9549999833106995, 0.965624988079071], 'Val Loss': [0.2765325605869293, 0.17862354218959808, 0.16632840037345886, 0.12927384674549103, 0.12569384276866913], 'Val Accuracy': [0.890999972820282, 0.9300000071525574, 0.9369999766349792, 0.9465000033378601, 0.9484999775886536]}, 'final_train_accuracy': 0.965624988079071, 'final_val_accuracy': 0.9484999775886536, 'test_accuracy': 0.9455000162124634, 'test_loss': 0.1481250375509262}

# %%
from google.colab import drive
drive.mount('/content/drive')
